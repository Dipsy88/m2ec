# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# /Users/Dipesh/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
values_df = pd.read_csv("values.csv", sep=",")
# randomize data
#values_df = values_df.reindex(np.random.permutation(values_df.index))

values_df
# Out:
#      Unnamed: 0                  From                To   Value
# 0             0         frankfurt_aws     frankfurt_aws  1.0000
# 1             1      frankfurt_google     frankfurt_aws  0.8140
# 2             2            london_aws     frankfurt_aws  0.6550
# 3             3         london_google     frankfurt_aws  0.5166
# 4             4            mumbai_aws     frankfurt_aws  0.3951
# 5             5         mumbai_google     frankfurt_aws  0.0569
# 6             6     northvirginia_aws     frankfurt_aws  0.4508
# 7             7  northvirginia_google     frankfurt_aws  0.3969
# 8             8            oregon_aws     frankfurt_aws  0.3358
# 9             9         oregon_google     frankfurt_aws  0.3240
# 10           10          saopaulo_aws     frankfurt_aws  0.2199
# 11           11       saopaulo_google     frankfurt_aws  0.2325
# 12           12         singapore_aws     frankfurt_aws  0.3204
# 13           13      singapore_google     frankfurt_aws  0.1414
# 14           14            sydney_aws     frankfurt_aws  0.1599
# 15           15         sydney_google     frankfurt_aws  0.1634
# 16           16             tokyo_aws     frankfurt_aws  0.2040
# 17           17          tokyo_google     frankfurt_aws  0.2106
# 18           18         frankfurt_aws  frankfurt_google  0.9096
# 19           19      frankfurt_google  frankfurt_google  1.0000
# 20           20            london_aws  frankfurt_google  0.6205
# 21           21         london_google  frankfurt_google  0.5426
# 22           22            mumbai_aws  frankfurt_google  0.2198
# 23           23         mumbai_google  frankfurt_google  0.0772
# 24           24     northvirginia_aws  frankfurt_google  0.4358
# 25           25  northvirginia_google  frankfurt_google  0.4063
# 26           26            oregon_aws  frankfurt_google  0.3579
# 27           27         oregon_google  frankfurt_google  0.3524
# 28           28          saopaulo_aws  frankfurt_google  0.2476
# 29           29       saopaulo_google  frankfurt_google  0.2536
# ..          ...                   ...               ...     ...
# 294         294     northvirginia_aws         tokyo_aws  0.3282
# 295         295  northvirginia_google         tokyo_aws  0.3117
# 296         296            oregon_aws         tokyo_aws  0.4292
# 297         297         oregon_google         tokyo_aws  0.3947
# 298         298          saopaulo_aws         tokyo_aws  0.1694
# 299         299       saopaulo_google         tokyo_aws  0.1662
# 300         300         singapore_aws         tokyo_aws  0.4618
# 301         301      singapore_google         tokyo_aws  0.4212
# 302         302            sydney_aws         tokyo_aws  0.3742
# 303         303         sydney_google         tokyo_aws  0.3680
# 304         304             tokyo_aws         tokyo_aws  1.0000
# 305         305          tokyo_google         tokyo_aws  0.6346
# 306         306         frankfurt_aws      tokyo_google  0.2127
# 307         307      frankfurt_google      tokyo_google  0.2424
# 308         308            london_aws      tokyo_google  0.2530
# 309         309         london_google      tokyo_google  0.2418
# 310         310            mumbai_aws      tokyo_google  0.3698
# 311         311         mumbai_google      tokyo_google  0.3650
# 312         312     northvirginia_aws      tokyo_google  0.3429
# 313         313  northvirginia_google      tokyo_google  0.3726
# 314         314            oregon_aws      tokyo_google  0.4185
# 315         315         oregon_google      tokyo_google  0.4046
# 316         316          saopaulo_aws      tokyo_google  0.1863
# 317         317       saopaulo_google      tokyo_google  0.1918
# 318         318         singapore_aws      tokyo_google  0.4579
# 319         319      singapore_google      tokyo_google  0.4476
# 320         320            sydney_aws      tokyo_google  0.3972
# 321         321         sydney_google      tokyo_google  0.3688
# 322         322             tokyo_aws      tokyo_google  0.7992
# 323         323          tokyo_google      tokyo_google  1.0000
#
# [324 rows x 4 columns]

# %%
df = values_df.pivot(index="From", columns="To", values="Value")
trX = df.values
trX.shape
# Out:
# (18, 18)

# %%
#trX

# %%
df
# Out:
# To                    frankfurt_aws  frankfurt_google  london_aws  \
# From
# frankfurt_aws                1.0000            0.9096      0.6694
# frankfurt_google             0.8140            1.0000      0.5994
# london_aws                   0.6550            0.6205      1.0000
# london_google                0.5166            0.5426      0.9433
# mumbai_aws                   0.3951            0.2198      0.3910
# mumbai_google                0.0569            0.0772      0.0730
# northvirginia_aws            0.4508            0.4358      0.4940
# northvirginia_google         0.3969            0.4063      0.4412
# oregon_aws                   0.3358            0.3579      0.3292
# oregon_google                0.3240            0.3524      0.3469
# saopaulo_aws                 0.2199            0.2476      0.2320
# saopaulo_google              0.2325            0.2536      0.2491
# singapore_aws                0.3204            0.1460      0.3259
# singapore_google             0.1414            0.1430      0.1353
# sydney_aws                   0.1599            0.1724      0.1660
# sydney_google                0.1634            0.1506      0.1672
# tokyo_aws                    0.2040            0.2350      0.2326
# tokyo_google                 0.2106            0.2374      0.2360
#
# To                    london_google  mumbai_aws  mumbai_google  \
# From
# frankfurt_aws                0.6053      0.3891         0.0759
# frankfurt_google             0.8098      0.2038         0.0676
# london_aws                   0.9988      0.3836         0.0829
# london_google                1.0000      0.2038         0.0892
# mumbai_aws                   0.2220      1.0000         0.9528
# mumbai_google                0.0912      0.9186         1.0000
# northvirginia_aws            0.4666      0.2874         0.1746
# northvirginia_google         0.4282      0.2021         0.1863
# oregon_aws                   0.3694      0.2400         0.2447
# oregon_google                0.3545      0.2044         0.2579
# saopaulo_aws                 0.2597      0.0908         0.0283
# saopaulo_google              0.2822      0.0455         0.0328
# singapore_aws                0.1592      0.4717         0.4776
# singapore_google             0.1724      0.4817         0.4808
# sydney_aws                   0.1854      0.1938         0.3494
# sydney_google                0.1704      0.3116         0.3306
# tokyo_aws                    0.2500      0.3622         0.3653
# tokyo_google                 0.2655      0.3732         0.3720
#
# To                    northvirginia_aws  northvirginia_google  oregon_aws  \
# From
# frankfurt_aws                    0.4606                0.4343      0.3303
# frankfurt_google                 0.4174                0.4246      0.3326
# london_aws                       0.4674                0.4506      0.3667
# london_google                    0.4402                0.4460      0.3480
# mumbai_aws                       0.2954                0.2204      0.2412
# mumbai_google                    0.1574                0.1868      0.2256
# northvirginia_aws                1.0000                0.9522      0.4580
# northvirginia_google             0.8862                1.0000      0.4656
# oregon_aws                       0.4587                0.4938      1.0000
# oregon_google                    0.4602                0.4562      0.5950
# saopaulo_aws                     0.3658                0.3660      0.2901
# saopaulo_google                  0.3584                0.4064      0.2727
# singapore_aws                    0.2280                0.2556      0.3255
# singapore_google                 0.2400                0.2745      0.3114
# sydney_aws                       0.2734                0.2828      0.3684
# sydney_google                    0.2580                0.2725      0.3000
# tokyo_aws                        0.3296                0.3394      0.3904
# tokyo_google                     0.3306                0.3710      0.3992
#
# To                    oregon_google  saopaulo_aws  saopaulo_google  \
# From
# frankfurt_aws                0.3475        0.2424           0.2441
# frankfurt_google             0.3586        0.2268           0.2296
# london_aws                   0.3683        0.2568           0.2670
# london_google                0.3688        0.2428           0.2458
# mumbai_aws                   0.2221        0.1106           0.0588
# mumbai_google                0.2762        0.0154           0.0142
# northvirginia_aws            0.4878        0.3658           0.3714
# northvirginia_google         0.5142        0.3400           0.3416
# oregon_aws                   0.6598        0.3022           0.2944
# oregon_google                1.0000        0.2858           0.2857
# saopaulo_aws                 0.3063        1.0000           0.9016
# saopaulo_google              0.3342        0.6844           1.0000
# singapore_aws                0.3352        0.1034           0.1031
# singapore_google             0.3688        0.0912           0.0900
# sydney_aws                   0.3259        0.1132           0.1310
# sydney_google                0.3374        0.1119           0.1108
# tokyo_aws                    0.4266        0.1599           0.1968
# tokyo_google                 0.4670        0.1712           0.1725
#
# To                    singapore_aws  singapore_google  sydney_aws  \
# From
# frankfurt_aws                0.3299            0.1388      0.1598
# frankfurt_google             0.1416            0.1572      0.1466
# london_aws                   0.3316            0.1690      0.1660
# london_google                0.1587            0.1730      0.1610
# mumbai_aws                   0.4830            0.4674      0.2008
# mumbai_google                0.4843            0.4852      0.3114
# northvirginia_aws            0.2236            0.2648      0.2690
# northvirginia_google         0.2480            0.2738      0.2530
# oregon_aws                   0.3253            0.3332      0.3656
# oregon_google                0.3359            0.3526      0.3000
# saopaulo_aws                 0.1030            0.1068      0.0750
# saopaulo_google              0.0984            0.1098      0.1118
# singapore_aws                1.0000            0.9044      0.2988
# singapore_google             0.7522            1.0000      0.3917
# sydney_aws                   0.2896            0.4270      1.0000
# sydney_google                0.4346            0.4454      0.6664
# tokyo_aws                    0.4716            0.4642      0.3850
# tokyo_google                 0.4784            0.5142      0.3614
#
# To                    sydney_google  tokyo_aws  tokyo_google
# From
# frankfurt_aws                0.1646     0.2187        0.2127
# frankfurt_google             0.1733     0.2068        0.2424
# london_aws                   0.1862     0.2328        0.2530
# london_google                0.1927     0.2204        0.2418
# mumbai_aws                   0.3230     0.3584        0.3698
# mumbai_google                0.3688     0.3406        0.3650
# northvirginia_aws            0.2847     0.3282        0.3429
# northvirginia_google         0.2964     0.3117        0.3726
# oregon_aws                   0.3213     0.4292        0.4185
# oregon_google                0.3462     0.3947        0.4046
# saopaulo_aws                 0.1306     0.1694        0.1863
# saopaulo_google              0.1377     0.1662        0.1918
# singapore_aws                0.4126     0.4618        0.4579
# singapore_google             0.4874     0.4212        0.4476
# sydney_aws                   0.9674     0.3742        0.3972
# sydney_google                1.0000     0.3680        0.3688
# tokyo_aws                    0.4027     1.0000        0.7992
# tokyo_google                 0.4382     0.6346        1.0000

# %%
visible_units = 18
hidden_units = 6
vb = tf.placeholder('float', [visible_units])
hb = tf.placeholder('float', [hidden_units])
W = tf.placeholder('float', [visible_units, hidden_units])

# %%
# 1. Forward pass
v0 =tf.placeholder('float', [None, visible_units])
_h0 = tf.nn.sigmoid(tf.matmul(v0, W) + hb)
h0 = tf.nn.relu(tf.sign(_h0 - tf.random_uniform(tf.shape(_h0))))

# 2. Backward pass (reconstruction)
_v1 = tf.nn.sigmoid(tf.matmul(h0, tf.transpose(W)) + vb)
v1 = tf.nn.relu(tf.sign(_v1 - tf.random_uniform(tf.shape(_v1))))
h1 = tf.nn.sigmoid(tf.matmul(v1, W) + hb)

# %%
# learning rate
alpha = 0.5
# gradients
w_pos_grad = tf.matmul(tf.transpose(v0),h0)
w_neg_grad = tf.matmul(tf.transpose(v1),h1)
# Contrastive divergence
CD = (w_pos_grad - w_neg_grad)/tf.to_float(tf.shape(v0)[0])
# update weights and biases
update_w = W + alpha*CD
update_vb = vb + alpha * tf.reduce_mean(v0-v1, 0) 
update_hb = hb + alpha * tf.reduce_mean(h0-h1, 0)

# %%
# error function set as Mean Absolute Error Function
error = v0 - v1
errors_sum = tf.reduce_mean(error*error)

# %%
# initialize variables
curr_w = np.zeros([visible_units, hidden_units], np.float32)
curr_vb = np.zeros([visible_units], np.float32)
curr_hb = np.zeros([hidden_units], np.float32)

prev_w = np.zeros([visible_units, hidden_units], np.float32)
prev_vb = np.zeros([visible_units], np.float32)
prev_hb = np.zeros([hidden_units], np.float32)


sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
epochs = 100
batch_size = 4
errors = []
for epoch in range(epochs):
    for start, end in zip(range(0, len(trX), batch_size), range (batch_size, len(trX), batch_size)):
        data = trX[start:end]
        curr_w = sess.run(update_w, feed_dict={v0: data, W: prev_w, vb:prev_vb, hb:prev_hb})
        curr_hb = sess.run(update_hb, feed_dict={v0: data, W: prev_w, vb:prev_vb, hb:prev_hb})
        curr_vb = sess.run(update_vb, feed_dict={v0: data, W: prev_w, vb:prev_vb, hb:prev_hb})
    
        prev_w = curr_w
        prev_vb = curr_vb
        prev_hb = curr_hb
        
    errors.append(sess.run(errors_sum, feed_dict={v0: trX, W: curr_w, vb: curr_vb, hb: curr_hb}))
    print(errors[-1])

plt.plot(errors)
plt.xlabel('Epoch')
plt.ylabel('Errors')
plt.show()
# Out:
# 0.3191042
# 0.268711
# 0.2749783
# 0.28553385
# 0.27111283
# 0.29778326
# 0.29230854
# 0.29581165
# 0.2536851
# 0.28759125
# 0.2774857
# 0.2864246
# 0.25773817
# 0.2533215
# 0.27423814
# 0.25425485
# 0.26967955
# 0.2781431
# 0.27109188
# 0.28110668
# 0.28140116
# 0.29100052
# 0.23395117
# 0.2564888
# 0.2730289
# 0.23404807
# 0.25893074
# 0.24513753
# 0.26545483
# 0.25626162
# 0.27427706
# 0.28557894
# 0.2658104
# 0.23413016
# 0.26342645
# 0.221853
# 0.26895484
# 0.23109375
# 0.24305177
# 0.24744496
# 0.21655546
# 0.24130358
# 0.26624
# 0.23226595
# 0.24813259
# 0.27162644
# 0.26156408
# 0.25566286
# 0.24058199
# 0.27752337
# 0.28460363
# 0.25657335
# 0.2538357
# 0.2239678
# 0.22497399
# 0.25279063
# 0.26377517
# 0.2517925
# 0.24313135
# 0.24196102
# 0.2257431
# 0.25191042
# 0.25090918
# 0.25281346
# 0.24607645
# 0.2545783
# 0.24578136
# 0.24702397
# 0.23398879
# 0.2620567
# 0.23125978
# 0.25108075
# 0.26110914
# 0.26166162
# 0.2793851
# 0.2772357
# 0.23834741
# 0.25482088
# 0.23422952
# 0.24526778
# 0.24437335
# 0.24542274
# 0.22945854
# 0.2526388
# 0.24015795
# 0.26184246
# 0.22932646
# 0.2538431
# 0.23489803
# 0.22013262
# 0.2618672
# 0.2269863
# 0.24905668
# 0.25288817
# 0.27168757
# 0.23675732
# 0.2605684
# 0.24589002
# 0.2545993
# 0.2608499

# %%
#selecting input
input = trX[0].reshape(1,-1)
input[0]
# Out:
# array([1.    , 0.9096, 0.6694, 0.6053, 0.3891, 0.0759, 0.4606, 0.4343,
#        0.3303, 0.3475, 0.2424, 0.2441, 0.3299, 0.1388, 0.1598, 0.1646,
#        0.2187, 0.2127])

# %%
# Feeding in the datacenter and reconstructing the input
hh0 = tf.nn.sigmoid(tf.matmul(v0,W) + hb)
vv1 = tf.nn.sigmoid(tf.matmul(hh0, tf.transpose(W))+vb)
feed = sess.run(hh0, feed_dict={v0:input,W:curr_w,hb:curr_hb})
rec = sess.run(vv1, feed_dict={hh0:feed, W:curr_w, vb:curr_vb})

# %%
rec[0]
# Out:
# array([0.44578612, 0.42872596, 0.58271706, 0.46271473, 0.21961473,
#        0.12662478, 0.5498575 , 0.5728086 , 0.50299746, 0.5255458 ,
#        0.4569627 , 0.35572964, 0.29867342, 0.18150501, 0.24734566,
#        0.2927155 , 0.26578352, 0.31750545], dtype=float32)

# %%
# list all the recommended dc in descending order
datacenter_df = pd.read_csv('Datacenters.csv',sep=',')
datacenter_df.head()
# Out:
#    DataCenterId              Name
# 0             0     frankfurt_aws
# 1             1  frankfurt_google
# 2             2        london_aws
# 3             3     london_google
# 4             4        mumbai_aws

# %%
df_mock = datacenter_df.assign(RecommendationScore=rec[0])
df_mock.sort_values(['RecommendationScore'], ascending=False)
# Out:
#     DataCenterId                  Name  RecommendationScore
# 2              2            london_aws             0.582717
# 7              7  northvirginia_google             0.572809
# 6              6     northvirginia_aws             0.549857
# 9              9         oregon_google             0.525546
# 8              8            oregon_aws             0.502997
# 3              3         london_google             0.462715
# 10            10          saopaulo_aws             0.456963
# 0              0         frankfurt_aws             0.445786
# 1              1      frankfurt_google             0.428726
# 11            11       saopaulo_google             0.355730
# 17            17          tokyo_google             0.317505
# 12            12         singapore_aws             0.298673
# 15            15         sydney_google             0.292715
# 16            16             tokyo_aws             0.265784
# 14            14            sydney_aws             0.247346
# 4              4            mumbai_aws             0.219615
# 13            13      singapore_google             0.181505
# 5              5         mumbai_google             0.126625

# %%
df_mock = datacenter_df[df_mock['Name'].isin(values_df.columns)]
df_mock = datacenter_df.assign(RecommendationScore=rec[0])
df_mock.sort_values(['RecommendationScore'], ascending=False)
# Out:
#     DataCenterId                  Name  RecommendationScore
# 2              2            london_aws             0.582717
# 7              7  northvirginia_google             0.572809
# 6              6     northvirginia_aws             0.549857
# 9              9         oregon_google             0.525546
# 8              8            oregon_aws             0.502997
# 3              3         london_google             0.462715
# 10            10          saopaulo_aws             0.456963
# 0              0         frankfurt_aws             0.445786
# 1              1      frankfurt_google             0.428726
# 11            11       saopaulo_google             0.355730
# 17            17          tokyo_google             0.317505
# 12            12         singapore_aws             0.298673
# 15            15         sydney_google             0.292715
# 16            16             tokyo_aws             0.265784
# 14            14            sydney_aws             0.247346
# 4              4            mumbai_aws             0.219615
# 13            13      singapore_google             0.181505
# 5              5         mumbai_google             0.126625

# %%
prev_w
# Out:
# array([[-0.22107181, -0.5772951 , -0.30023116, -0.52736866, -1.3408656 ,
#         -1.1439862 ],
#        [ 0.31694144, -0.69038135, -0.17408036, -0.3771813 , -0.90554404,
#         -1.5088031 ],
#        [ 0.21197776, -0.77362037, -0.15663601, -0.62680197, -1.5435387 ,
#         -1.267734  ],
#        [ 1.2251738 , -0.6216275 ,  0.04582078, -0.50810474, -1.247595  ,
#         -1.4990112 ],
#        [ 0.00759255,  0.50469685, -0.34219044, -0.31656125, -0.03924999,
#          1.0092534 ],
#        [ 0.68196505,  0.60818154, -0.33724698, -0.17122598,  0.32299998,
#          1.9022774 ],
#        [ 1.1796496 , -0.28034374, -0.26785964, -0.29411322, -1.0564446 ,
#         -1.1389343 ],
#        [-0.21283536, -0.3381486 , -0.2901333 , -0.41132936, -1.14627   ,
#         -1.175473  ],
#        [-0.23296446, -0.32958215, -0.18085067, -0.1475806 , -0.9394722 ,
#         -1.021975  ],
#        [ 0.63087404, -0.29424825, -0.31161484, -0.26255196, -0.8498947 ,
#         -0.39435738],
#        [-1.3219986 , -0.7312596 , -0.3433243 , -0.06467836, -1.1687394 ,
#         -2.0246859 ],
#        [-0.1641971 , -0.8341602 , -0.3567065 , -0.07725999, -1.2412096 ,
#         -1.8306602 ],
#        [ 1.0568775 ,  0.22835204, -0.27652496, -0.36019406, -0.19727208,
#          0.91797954],
#        [ 1.679007  ,  0.3581289 , -0.1965287 , -0.2239817 , -0.02585995,
#          1.3215921 ],
#        [ 0.180087  ,  0.41329712, -0.40528038, -0.16983977, -0.6261729 ,
#          1.2639326 ],
#        [-0.826933  ,  0.5695932 , -0.33296227, -0.16191165, -0.81064343,
#          1.4314325 ],
#        [ 0.86110556,  0.15265837, -0.23417832, -0.21587339, -0.35895264,
#          0.43035054],
#        [ 0.60808986, -0.02031906, -0.41615725, -0.45987105, -0.5595085 ,
#          0.33936456]], dtype=float32)

# %%
weight = tf.convert_to_tensor(prev_w, dtype = tf.float32, preferred_dtype=tf.float32)

# %%
weight
# Out:
# <tf.Tensor 'Const_10:0' shape=(24, 8) dtype=float32>

# %% [markdown]
# <h3>Save the model</h3>

# %%
saver = tf.train.Saver()

# %%
save_path = saver.save(sess, '/Users/Dipesh/OneDrive/Research_Engineer/Papers/M2EC/code/RecommendationSystem/tmp/my_model.ckpt')
print("Model saved in path: %s" % save_path)
# Out:
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# <class 'numpy.float32'> has type type, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# <class 'numpy.float32'> has type type, but expected one of: int, long, bool
# Model saved in path: /Users/Dipesh/OneDrive/Research_Engineer/Papers/M2EC/code/RecommendationSystem/tmp/my_model.ckpt

# %%
sess.run(weight)
# Out:
# array([[-0.848394  , -0.9462479 ,  1.456084  , -0.6242631 , -0.3689344 ,
#         -0.99426264, -0.68724   , -3.3351161 ],
#        [-0.8025334 , -0.83906364, -0.6903543 , -1.0720041 , -0.5372855 ,
#         -0.84587276, -0.83790594, -0.6213941 ],
#        [-0.906363  , -0.87763035, -3.461344  , -0.79708564, -0.5265902 ,
#         -0.92724556, -0.7421442 ,  0.14221789],
#        [-0.97398174, -1.2460415 ,  0.04553863, -0.8436854 , -0.4715334 ,
#         -1.5132608 , -0.9818517 , -3.961344  ],
#        [-1.1901635 , -1.01936   , -1.0102628 , -1.1449157 , -0.41590428,
#         -1.0286233 , -0.8851782 , -0.83656186],
#        [-1.5719172 , -0.6598005 , -3.3389657 , -0.82791007, -0.58414996,
#         -1.0345184 , -0.8185393 , -0.0953274 ],
#        [ 1.58662   , -1.1116134 , -0.6704497 , -1.2836905 , -0.8279579 ,
#          0.4441759 , -0.3444743 , -0.8917348 ],
#        [ 2.6477065 , -0.93333346, -2.848846  , -1.2239838 , -0.88942814,
#          0.97497374, -0.25690544,  0.07004298],
#        [-0.62782377, -0.66942596,  1.1308086 , -0.7221187 , -0.4098406 ,
#         -0.88751614, -0.4081286 , -3.4072182 ],
#        [-0.9652476 , -0.8457546 ,  0.7075877 , -0.95508265, -0.61451167,
#         -0.9279495 , -0.4870908 ,  1.1712747 ],
#        [-1.232931  , -0.5921903 , -3.24184   , -0.44443643, -0.6058823 ,
#         -1.1169502 , -0.44054675,  2.1890283 ],
#        [-0.79007024, -0.9219407 ,  1.7917365 , -0.6249061 , -0.45406595,
#         -1.0569853 , -0.583037  , -3.5215702 ],
#        [-1.0460788 , -0.89880204,  0.7400627 , -0.90631497, -0.7234918 ,
#         -0.78807217, -0.2094637 ,  0.4663741 ],
#        [-0.50677377, -0.6313554 , -2.6954482 , -1.0277095 , -0.60971963,
#         -0.6003863 , -0.4200873 ,  0.94180304],
#        [-0.98197937, -1.0162286 , -0.32725787, -0.9837717 , -0.33565727,
#         -1.424102  , -0.9997541 , -3.6652415 ],
#        [-1.5313786 , -0.10576283,  0.03189747,  0.3525997 , -0.30898502,
#         -1.2077283 , -0.03149138,  0.8093978 ],
#        [-1.5626485 ,  0.03532333, -2.5141869 ,  0.68173206, -0.151231  ,
#         -1.1692258 ,  0.22785167,  0.51097465],
#        [ 0.22440816, -0.7455464 ,  1.1239669 , -0.5695025 , -0.18816504,
#         -0.39078462, -0.17930812, -3.17004   ],
#        [ 1.2619758 , -0.91530126,  0.03029131, -1.0997977 , -0.7766062 ,
#          0.07788092, -0.2181254 , -0.6280891 ],
#        [ 2.441362  , -0.9192308 , -3.0047615 , -1.199037  , -0.83336216,
#          0.29337594, -0.17184003,  0.7228324 ],
#        [ 0.33858198, -0.7668368 ,  0.6077083 , -0.64570934, -0.52346975,
#         -0.04667405, -0.08554364,  0.05217377],
#        [ 1.1406599 , -0.6355595 , -2.4331021 , -0.8238013 , -0.6610715 ,
#          0.02298614, -0.28850406,  1.1608156 ],
#        [ 0.21476111, -0.7966757 ,  0.5071939 , -0.88800216, -0.6382282 ,
#         -0.14227544, -0.15283158,  0.209802  ],
#        [ 0.56622976, -0.6907769 , -2.7134914 , -0.81479895, -0.7596126 ,
#         -0.38132223, -0.42805627,  0.5965374 ]], dtype=float32)

# %%
import os
from tensorflow.contrib.tensorboard.plugins import projector
summary_writer = tf.summary.FileWriter('/Users/Dipesh/OneDrive/Research_Engineer/Papers/M2EC/code/RecommendationSystem/tmp/my_model.ckpt', sess.graph)
config = projector.ProjectorConfig()
embedding_conf = config.embeddings.add()
# embedding_conf.tensor_name = ‘embedding:0’
embedding_conf.metadata_path = os.path.join('/Users/Dipesh/OneDrive/Research_Engineer/Papers/M2EC/code/RecommendationSystem/tmp/my_model.ckpt', 'metadata.tsv')
projector.visualize_embeddings(summary_writer, config)
# Out:
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# <class 'numpy.float32'> has type type, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# <class 'numpy.float32'> has type type, but expected one of: int, long, bool

# %%
prev_w
# Out:
# array([[-2.918111  ,  0.7700846 , -1.0267539 , -0.4451885 , -0.21534048,
#         -0.64004344,  0.93250537, -1.4006436 ],
#        [-0.1476582 , -0.41345018, -0.50239676, -1.2330731 , -0.39082175,
#         -0.8551086 , -0.2848084 , -0.42968494],
#        [ 0.42128938, -2.377184  , -0.6504189 , -1.4092538 , -0.67709804,
#         -0.6655717 , -1.972765  , -0.57696134],
#        [-3.327949  ,  0.15270992, -1.8314408 , -1.02406   , -0.4006565 ,
#         -0.8831462 ,  0.23887405, -1.8585616 ],
#        [ 0.16659045, -0.44784445, -0.6848213 , -1.257686  , -0.5190715 ,
#         -0.8056637 , -0.20006447, -0.2758151 ],
#        [ 0.14910981, -2.3412678 , -1.2521117 , -1.3898255 , -0.6119462 ,
#         -0.6014848 , -1.9017382 , -0.6401987 ],
#        [-1.0736653 , -0.32411486,  1.7548801 , -0.86349714,  0.07445063,
#         -0.7969162 , -0.15183516,  0.98447615],
#        [-1.5118722 , -1.8200159 ,  2.0655758 , -0.7127766 ,  0.11025594,
#         -0.6582782 , -1.8557818 ,  1.1045442 ],
#        [-2.7662003 ,  0.507935  , -1.3060644 , -0.63844293, -0.2628791 ,
#         -0.6807341 ,  0.37656492, -1.4192349 ],
#        [ 0.2650684 , -0.09540744, -0.27417257, -1.1108764 , -0.43882936,
#         -0.7890652 ,  0.08517252, -0.43598285],
#        [ 0.35228157, -2.1304739 , -0.10445145, -1.2505091 , -0.6023737 ,
#         -0.44874465, -1.9695643 , -0.40471902],
#        [-2.7451673 ,  0.942954  , -1.3496978 , -0.75610346,  0.02546665,
#         -0.7238883 ,  0.9803721 , -1.7138398 ],
#        [ 1.1379315 ,  0.6850554 ,  0.51935184, -0.89581513, -0.17577413,
#         -0.6488375 ,  0.8029212 , -0.2130826 ],
#        [ 0.2796165 , -2.3153284 ,  0.488592  , -1.026791  , -0.5976661 ,
#         -0.48502818, -1.9815648 ,  0.38693395],
#        [-3.4792793 ,  0.23997572, -1.493885  , -0.930523  , -0.56914794,
#         -0.8930984 ,  0.18229827, -1.7568153 ],
#        [ 0.7007065 , -0.3111758 , -1.1710173 , -0.8159188 , -0.14591528,
#         -0.21639475, -0.22929887, -0.599152  ],
#        [ 1.3034468 , -1.5866697 , -1.2885925 , -1.1464003 , -0.48613083,
#         -0.11691704, -1.4138308 , -0.6022602 ],
#        [-2.4905179 , -0.04478614, -0.88357794,  0.06392509,  0.06068574,
#         -0.25859243,  0.5984416 , -1.0934967 ],
#        [-0.43855202, -0.11858746,  1.1980675 , -0.78097385,  0.40151152,
#         -0.7495187 , -0.02500037,  1.1104279 ],
#        [ 0.5912974 , -1.9534225 ,  1.9800959 , -0.88844   ,  0.5955367 ,
#         -0.71324635, -1.8082825 ,  1.5722411 ],
#        [-0.0102409 , -0.07097296,  0.60918045, -0.65239817, -0.08779161,
#         -0.55897087, -0.0055551 ,  0.3606368 ],
#        [ 0.01793881, -2.0699303 ,  0.74589646, -0.9252796 , -0.11711719,
#         -0.49766597, -1.9957994 ,  0.5119984 ],
#        [ 0.7310766 ,  0.8096386 ,  0.72324675, -0.4248343 ,  0.07043031,
#         -0.30540556,  1.1114982 ,  0.55401516],
#        [ 0.15489763, -1.8434403 ,  0.75653374, -0.9207038 , -0.0098405 ,
#         -0.53410363, -1.7753539 ,  0.40109548]], dtype=float32)

# %%
embedding_var = tf.get_variable(name='embeddingAa',
                                 initializer=prev_w)

# %%
embedding_var
# Out:
# <tf.Variable 'embeddingA:0' shape=(24, 8) dtype=float32_ref>

# %%
from tensorflow.contrib.tensorboard.plugins import projector

with tf.Session() as session:
    # Create summary writer.
    writer = tf.summary.FileWriter('/Users/Dipesh/OneDrive/Research_Engineer/Papers/M2EC/code/RecommendationSystem/tmp2', session.graph)
    # Initialize embedding_var
    session.run(embedding_var.initializer)
    # Create Projector config
    config = projector.ProjectorConfig()
    # Add embedding visualizer
    embedding = config.embeddings.add()
    # Attach the name 'embedding'
    embedding.tensor_name = embedding_var.name
    # Metafile which is described later
    embedding.metadata_path = '/Users/Dipesh/OneDrive/Research_Engineer/Papers/M2EC/code/RecommendationSystem/tmp2/metadata.tsv'
    # Add writer and config to Projector
    projector.visualize_embeddings(writer, config)
    # Save the model
    saver_embed = tf.train.Saver([embedding_var])
    saver_embed.save(session, '/Users/Dipesh/OneDrive/Research_Engineer/Papers/M2EC/code/RecommendationSystem/tmp2/embedding_test.ckpt', 1)

writer.close()
# Out:
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# <class 'numpy.float32'> has type type, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# <class 'numpy.float32'> has type type, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# <class 'numpy.float32'> has type type, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# <class 'numpy.float32'> has type type, but expected one of: int, long, bool

# %%
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

# %%
tsne = TSNE(n_components=2)
tsne_results = tsne.fit_transform(prev_w)

# %%
def showPlot(points):
    plt.rcParams['figure.figsize'] = (16, 8)
    for i, point in enumerate(points):
        plt.scatter(point[0], point[1])

show_2Dplot(tsne_results)
