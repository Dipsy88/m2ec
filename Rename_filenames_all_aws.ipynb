# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

path = "/Users/Dipesh/OneDrive/Research_Engineer/Papers/M2EC/results/aws_all/"

# %%
for dir in os.listdir(path):
    if "." in dir:
        continue
    for file in os.listdir(path+dir):
        original_name=file
        #replace bandwidth in string to  make it consistent
        file = file.replace("bandwidth", "combined_bandwidth_aws")
        # replace latency
        file = file.replace("latency" , "combined_latency_aws")

        if '14' in dir:
            file = file.replace ('14.txt', 'tokyo_aws.txt')
        elif '13' in dir:
            file = file.replace ('13.txt', 'sydney_aws.txt')
        elif '12' in dir:
            file = file.replace ('12.txt', 'singapore_aws.txt')
        elif '11' in dir:
            file = file.replace ('11.txt', 'seoul_aws.txt')
        elif '10' in dir:
            file = file.replace ('10.txt', 'saopaulo_aws.txt')
        elif '9' in dir:
            file = file.replace ('9.txt', 'paris_aws.txt')
        elif '8' in dir:
            file = file.replace ('8.txt', 'oregon_aws.txt')
        elif '7' in dir:
            file = file.replace ('7.txt', 'ohio_aws.txt')
        elif '6' in dir:
            file = file.replace ('6.txt', 'northvirginia_aws.txt')
        elif '5' in dir:
            file = file.replace ('5.txt', 'northcalifornia_aws.txt')
        elif '4' in dir:
            file = file.replace ('4.txt', 'mumbai_aws.txt')
        elif '3' in dir:
            file = file.replace ('3.txt', 'london_aws.txt')
        elif '2' in dir:
            file = file.replace ('2.txt', 'ireland_aws.txt')
        elif '1' in dir:
            file = file.replace ('1.txt', 'frankfurt_aws.txt')
        elif '0' in dir:
            file = file.replace ('0.txt', 'central_aws.txt')
                    
        if '_14' in file:
            file = file.replace ('_14', '_tokyo_aws_')
        elif '_13' in file:
            file = file.replace ('_13', '_sydney_aws_')
        elif '_12' in file:
            file = file.replace ('_12', '_singapore_aws_')
        elif '_11' in file:
            file = file.replace ('_11', '_seoul_aws_')
        elif '_10' in file:
            file = file.replace ('_10', '_saopaulo_aws_')
        elif '_9' in file:
            file = file.replace ('_9', '_paris_aws_')
        elif '_8' in file:
            file = file.replace ('_8', '_oregon_aws_')
        elif '_7' in file:
            file = file.replace ('_7', '_ohio_aws_')
        elif '_6' in file:
            file = file.replace ('_6', '_northvirginia_aws_')
        elif '_5' in file:
            file = file.replace ('_5', '_northcalifornia_aws_')
        elif '_4' in file:
            file = file.replace ('_4', '_mumbai_aws_')
        elif '_3' in file:
            file = file.replace ('_3', '_london_aws_')
        elif '_2' in file:
            file = file.replace ('_2', '_ireland_aws_')
        elif '_1' in file:
            file = file.replace ('_1', '_frankfurt_aws_')
        elif '_0' in file:
            file = file.replace ('_0', '_central_aws_')
            
        os.rename(os.path.join(path,dir,original_name), os.path.join(path, dir, file))
